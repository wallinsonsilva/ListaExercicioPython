# %% [markdown]
# <a href="https://colab.research.google.com/github/wallinsonsilva/ListaExercicioPython/blob/master/MergeDadosRNComRegiaoSaudeGeoSES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm

# %%
acumulado_rn = pd.read_csv('/content/drive/My Drive/Projeto Ciencia de dados - COVID 19/Dados Gerados/ET_CASOS_ACUMULADO_RN.csv')
acumulado_rn.head()
# Out:
#    codmun       municipio  ...  porcentagem_casos_hab porcentagem_obitos_casos
# 0  240010           Acari  ...               0.005478                 0.049180
# 1  240020             Açu  ...               0.020115                 0.043702
# 2  240030  Afonso Bezerra  ...               0.009153                 0.059406
# 3  240040       Água Nova  ...               0.006150                 0.000000
# 4  240050      Alexandria  ...               0.003241                 0.090909
#
# [5 rows x 9 columns]

# %%
acumulado_rn.describe()
# Out:
#               codmun  ...  porcentagem_obitos_casos
# count     167.000000  ...                167.000000
# mean   240764.191617  ...                  0.034239
# std       440.349969  ...                  0.044999
# min    240010.000000  ...                  0.000000
# 25%    240377.500000  ...                  0.004649
# 50%    240760.000000  ...                  0.027027
# 75%    241146.000000  ...                  0.046244
# max    241500.000000  ...                  0.375000
#
# [8 rows x 7 columns]

# %%
regioes_saude = pd.read_csv('/content/drive/My Drive/Projeto Ciencia de dados - COVID 19/CIR RN/MUNICIPIOS POR REGIAO SAUDE RN.csv')
regioes_saude.CIR = regioes_saude.CIR.astype(str)
regioes_saude.CodRegiao = regioes_saude.CodRegiao.astype(str)
regioes_saude.head()
# Out:
#   CIR CodRegiao  ...       Municipio CodMunIBGE
# 0   4     24004  ...           Acari     240010
# 1   8     24008  ...             Açu     240020
# 2   3     24003  ...  Afonso Bezerra     240030
# 3   6     24006  ...       Água Nova     240040
# 4   6     24006  ...      Alexandria     240050
#
# [5 rows x 12 columns]

# %%
regioes_saude.isnull().sum()
# Out:
# CIR                          0
# CodRegiao                    0
# Sede                         0
# Região de Saúde              0
# Mesorregião Geográfica       0
# Nome_Mesorregião             0
# Microrregião Geográfica      0
# Nome_Microrregião            0
# Código Município             0
# Código Município Completo    0
# Municipio                    0
# CodMunIBGE                   0
# dtype: int64

# %%
casos_mun_reg = pd.merge(acumulado_rn, regioes_saude, left_on='codmun',right_on='CodMunIBGE')
casos_mun_reg.head()
# Out:
#     codmun municipio  ...  Municipio CodMunIBGE
# 88  240810     Natal  ...      Natal     240810
#
# [1 rows x 21 columns]

# %%
casos_mun_reg.to_csv('/content/drive/My Drive/Projeto Ciencia de dados - COVID 19/Dados Gerados/ET_casos_municipios_regiao.csv',index=False)

# %%
dados_ibge_rn = pd.read_excel('/content/drive/My Drive/Projeto Ciencia de dados - COVID 19/CIR RN/Dado IGBE 2017.xlsx')
dados_ibge_rn.head()
# Out:
#                  Município  ...  PIB per capita - R$
# 0         Rafael Fernandes  ...              7920.31
# 1                    Natal  ...             26497.08
# 2                  Mossoró  ...             20858.33
# 3               Parnamirim  ...             19720.13
# 4  São Gonçalo do Amarante  ...             13935.05
#
# [5 rows x 13 columns]

# %%
dados_ibge_rn.isnull().sum()
# Out:
# Município                                               0
# Código                                                  0
# Gentílico                                               0
# Prefeito                                                0
# Área Territorial - km²                                  0
# População estimada - pessoas                            0
# Densidade demográfica - hab/km²                         0
# Escolarização 6 a 14 anos                               0
# IDHM - Índice de desenvolvimento humano municipal       0
# Mortalidade infantil - óbitos por mil nascidos vivos    0
# Receitas realizadas - R$ (×1000)                        1
# Despesas empenhadas - R$ (×1000) [2017]                 1
# PIB per capita - R$                                     0
# dtype: int64

# %%
#Tratando valores nulos sem remover
dados_ibge_rn['Receitas realizadas - R$ (×1000)'] = dados_ibge_rn['Receitas realizadas - R$ (×1000)'].fillna(dados_ibge_rn['Receitas realizadas - R$ (×1000)'].mean())
dados_ibge_rn['Despesas empenhadas - R$ (×1000) [2017]'] = dados_ibge_rn['Despesas empenhadas - R$ (×1000) [2017]'].fillna(dados_ibge_rn['Despesas empenhadas - R$ (×1000) [2017]'].mean())
dados_ibge_rn.isnull().sum()
# Out:
# Município                                               0
# Código                                                  0
# Gentílico                                               0
# Prefeito                                                0
# Área Territorial - km²                                  0
# População estimada - pessoas                            0
# Densidade demográfica - hab/km²                         0
# Escolarização 6 a 14 anos                               0
# IDHM - Índice de desenvolvimento humano municipal       0
# Mortalidade infantil - óbitos por mil nascidos vivos    0
# Receitas realizadas - R$ (×1000)                        0
# Despesas empenhadas - R$ (×1000) [2017]                 0
# PIB per capita - R$                                     0
# dtype: int64

# %%
dados_ibge_rn = dados_ibge_rn.drop(['Município','Gentílico','Prefeito'],axis=1)
dados_ibge_rn.head()
# Out:
#     Código  ...  PIB per capita - R$
# 0  2410504  ...              7920.31
# 1  2408102  ...             26497.08
# 2  2408003  ...             20858.33
# 3  2403251  ...             19720.13
# 4  2412005  ...             13935.05
#
# [5 rows x 10 columns]

# %%
dados_ibge_rn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 10 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Código                                                167 non-null    int64
#  1   Área Territorial - km²                                167 non-null    float64
#  2   População estimada - pessoas                          167 non-null    int64
#  3   Densidade demográfica - hab/km²                       167 non-null    float64
#  4   Escolarização 6 a 14 anos                             167 non-null    float64
#  5   IDHM - Índice de desenvolvimento humano municipal     167 non-null    float64
#  6   Mortalidade infantil - óbitos por mil nascidos vivos  167 non-null    float64
#  7   Receitas realizadas - R$ (×1000)                      167 non-null    float64
#  8   Despesas empenhadas - R$ (×1000) [2017]               167 non-null    float64
#  9   PIB per capita - R$                                   167 non-null    float64
# dtypes: float64(8), int64(2)
# memory usage: 13.2 KB

# %%
dados_casos_mun_reg_ibge = pd.merge(casos_mun_reg,dados_ibge_rn,left_on='Código Município Completo',right_on='Código')
dados_casos_mun_reg_ibge.head()
# Out:
#    codmun  ... PIB per capita - R$
# 0  240010  ...            10508.72
# 1  240020  ...            15364.85
# 2  240030  ...             8556.54
# 3  240040  ...             7818.76
# 4  240050  ...             9054.32
#
# [5 rows x 31 columns]

# %%
dados_casos_mun_reg_ibge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 167 entries, 0 to 166
# Data columns (total 31 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   codmun                                                167 non-null    int64
#  1   municipio                                             167 non-null    object
#  2   codRegiaoSaude                                        167 non-null    int64
#  3   nomeRegiaoSaude                                       167 non-null    object
#  4   populacaoTCU2019                                      167 non-null    int64
#  5   casosAcumulado                                        167 non-null    int64
#  6   obitosAcumulado                                       167 non-null    int64
#  7   porcentagem_casos_hab                                 167 non-null    float64
#  8   porcentagem_obitos_casos                              167 non-null    float64
#  9   CIR                                                   167 non-null    object
#  10  CodRegiao                                             167 non-null    object
#  11  Sede                                                  167 non-null    object
#  12  Região de Saúde                                       167 non-null    object
#  13  Mesorregião Geográfica                                167 non-null    int64
#  14  Nome_Mesorregião                                      167 non-null    object
#  15  Microrregião Geográfica                               167 non-null    int64
#  16  Nome_Microrregião                                     167 non-null    object
#  17  Código Município                                      167 non-null    int64
#  18  Código Município Completo                             167 non-null    int64
#  19  Municipio                                             167 non-null    object
#  20  CodMunIBGE                                            167 non-null    int64
#  21  Código                                                167 non-null    int64
#  22  Área Territorial - km²                                167 non-null    float64
#  23  População estimada - pessoas                          167 non-null    int64
#  24  Densidade demográfica - hab/km²                       167 non-null    float64
#  25  Escolarização 6 a 14 anos                             167 non-null    float64
#  26  IDHM - Índice de desenvolvimento humano municipal     167 non-null    float64
#  27  Mortalidade infantil - óbitos por mil nascidos vivos  167 non-null    float64
#  28  Receitas realizadas - R$ (×1000)                      167 non-null    float64
#  29  Despesas empenhadas - R$ (×1000) [2017]               167 non-null    float64
#  30  PIB per capita - R$                                   167 non-null    float64
# dtypes: float64(10), int64(12), object(9)
# memory usage: 41.8+ KB

# %%
geoses = pd.read_csv('/content/drive/My Drive/Projeto Ciencia de dados - COVID 19/OpenSus/scores/nacional.csv')
geoses.head()
# Out:
#    v0002_codigo_do_municipio    GeoSES  ...   renda__VAR  segregacao__VAR
# 0                    1200013 -0.626435  ...  MED_RENDDOM  ICE_renda_preto
# 1                    1200054 -0.681931  ...  MED_RENDDOM  ICE_renda_preto
# 2                    1200104 -0.610734  ...  MED_RENDDOM  ICE_renda_preto
# 3                    1200138 -0.663709  ...  MED_RENDDOM  ICE_renda_preto
# 4                    1200179 -0.687890  ...  MED_RENDDOM  ICE_renda_preto
#
# [5 rows x 19 columns]

# %%
geoses.isnull().sum()
# Out:
# v0002_codigo_do_municipio    0
# GeoSES                       0
# PRIMEIRA__VAR                0
# SEGUNDA__VAR                 0
# TERCEIRA__VAR                0
# educação                     0
# mobilidade                   0
# pobreza                      0
# privacao_material            0
# riqueza                      0
# renda                        0
# segregacao                   0
# educação__VAR                0
# mobilidade__VAR              0
# pobreza__VAR                 0
# privacao_material__VAR       0
# riqueza__VAR                 0
# renda__VAR                   0
# segregacao__VAR              0
# dtype: int64

# %%
geoses = geoses[['v0002_codigo_do_municipio','GeoSES','educação','mobilidade','pobreza','privacao_material','riqueza','renda','segregacao']]
geoses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5565 entries, 0 to 5564
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   v0002_codigo_do_municipio  5565 non-null   int64
#  1   GeoSES                     5565 non-null   float64
#  2   educação                   5565 non-null   float64
#  3   mobilidade                 5565 non-null   int64
#  4   pobreza                    5565 non-null   float64
#  5   privacao_material          5565 non-null   float64
#  6   riqueza                    5565 non-null   float64
#  7   renda                      5565 non-null   float64
#  8   segregacao                 5565 non-null   float64
# dtypes: float64(7), int64(2)
# memory usage: 391.4 KB

# %%
dados_casos_mun_reg_ibge_geoses = pd.merge(dados_casos_mun_reg_ibge,geoses,left_on='Código Município Completo',right_on='v0002_codigo_do_municipio')
dados_casos_mun_reg_ibge_geoses
# Out:
#      codmun       municipio  codRegiaoSaude  ...   riqueza        renda  segregacao
# 0    240010           Acari           24004  ...  1.578662  1455.053300    0.122580
# 1    240020             Açu           24008  ...  1.099616  1646.173817    0.075290
# 2    240030  Afonso Bezerra           24003  ...  0.000000   984.783786    0.060091
# 3    240040       Água Nova           24006  ...  0.000000   798.149419    0.081219
# 4    240050      Alexandria           24006  ...  0.910539  1064.850212    0.085320
# ..      ...             ...             ...  ...       ...          ...         ...
# 162  241470          Várzea           24001  ...  0.433516  1016.895791    0.083188
# 163  241475       Venha-Ver           24006  ...  0.000000   769.777129    0.125785
# 164  241480       Vera Cruz           24001  ...  0.147214  1152.882696    0.081721
# 165  241490          Viçosa           24006  ...  0.000000   880.140015    0.049381
# 166  241500       Vila Flor           24001  ...  0.275899  1086.330553    0.070006
#
# [167 rows x 40 columns]

# %%
dados_casos_mun_reg_ibge_geoses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 167 entries, 0 to 166
# Data columns (total 40 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   codmun                                                167 non-null    int64
#  1   municipio                                             167 non-null    object
#  2   codRegiaoSaude                                        167 non-null    int64
#  3   nomeRegiaoSaude                                       167 non-null    object
#  4   populacaoTCU2019                                      167 non-null    int64
#  5   casosAcumulado                                        167 non-null    int64
#  6   obitosAcumulado                                       167 non-null    int64
#  7   porcentagem_casos_hab                                 167 non-null    float64
#  8   porcentagem_obitos_casos                              167 non-null    float64
#  9   CIR                                                   167 non-null    object
#  10  CodRegiao                                             167 non-null    object
#  11  Sede                                                  167 non-null    object
#  12  Região de Saúde                                       167 non-null    object
#  13  Mesorregião Geográfica                                167 non-null    int64
#  14  Nome_Mesorregião                                      167 non-null    object
#  15  Microrregião Geográfica                               167 non-null    int64
#  16  Nome_Microrregião                                     167 non-null    object
#  17  Código Município                                      167 non-null    int64
#  18  Código Município Completo                             167 non-null    int64
#  19  Municipio                                             167 non-null    object
#  20  CodMunIBGE                                            167 non-null    int64
#  21  Código                                                167 non-null    int64
#  22  Área Territorial - km²                                167 non-null    float64
#  23  População estimada - pessoas                          167 non-null    int64
#  24  Densidade demográfica - hab/km²                       167 non-null    float64
#  25  Escolarização 6 a 14 anos                             167 non-null    float64
#  26  IDHM - Índice de desenvolvimento humano municipal     167 non-null    float64
#  27  Mortalidade infantil - óbitos por mil nascidos vivos  167 non-null    float64
#  28  Receitas realizadas - R$ (×1000)                      167 non-null    float64
#  29  Despesas empenhadas - R$ (×1000) [2017]               167 non-null    float64
#  30  PIB per capita - R$                                   167 non-null    float64
#  31  v0002_codigo_do_municipio                             167 non-null    int64
#  32  GeoSES                                                167 non-null    float64
#  33  educação                                              167 non-null    float64
#  34  mobilidade                                            167 non-null    int64
#  35  pobreza                                               167 non-null    float64
#  36  privacao_material                                     167 non-null    float64
#  37  riqueza                                               167 non-null    float64
#  38  renda                                                 167 non-null    float64
#  39  segregacao                                            167 non-null    float64
# dtypes: float64(17), int64(14), object(9)
# memory usage: 53.5+ KB

# %%
dados_casos_mun_reg_ibge_geoses.to_csv('/content/drive/My Drive/Projeto Ciencia de dados - COVID 19/Dados Gerados/ET_dados_casos_mun_reg_igbe_geoses.csv',index=False)
